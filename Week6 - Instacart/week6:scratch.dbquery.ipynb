-- %%
select * from week6.silver_test.dq_gate;
select * from week6.silver_test.batch_dq_gate;
select * from week6.silver_test.dq_rejects_summary;
select * from week6.silver_test.dq_warnings_coverage;
select * from week6.silver_test.dq_warnings_summary;
select * from week6.silver_test.aisles_rejects;
select * from week6.silver_test.departments_rejects;
select * from week6.silver_test.products_rejects;
select * from week6.silver_test.orders_rejects;
select * from week6.silver_test.order_products_prior_rejects;
select * from week6.silver_test.order_products_train_rejects;
